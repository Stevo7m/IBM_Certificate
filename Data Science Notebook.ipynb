# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Steven Mobley**
# Data Scientist

# %% [markdown]
# I am interested in data science because I like working with data to solve difficult problems.

# %% [markdown]
# ### Below is an example of evaluating an arithmetic expression in Python

# %%
1+1
# Out:
# 2

# %% [markdown]
# Bulleted List:
#
# - Bullet Item 1
# - Bullet Item 2
# - Bullet Item 3
#
# Numbered List:
#
# 1. Number Item 1
# 2. Number Item 2
# 3. Number Item 3
#
# Table:
#
# | Table Header |
# | ------ |
# | Table Item 1 |
# | Table Item 2 |
# | Table Item 3 |
